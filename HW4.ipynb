# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaZarubkina/HomeworkPyton/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./kc_house_data.csv', sep=',', encoding='windows-1251')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %% [markdown]
# 1.2. Изучите стоимости недвижимости

# %%
sns.histplot(df['price'], bins=15)

plt.title('Стоимость недвижимости')
plt.xlabel('Стоимость')
plt.ylabel('Кол-во домов');

# %% [markdown]
# 1.3. Изучите распределение квадратуры жилой

# %%
sns.boxplot([df['sqft_living']], showfliers=False) #без выбросов
plt.title('Распределение состояния домов')
plt.legend(data.index);

# %% [markdown]
# 1.4. Изучите распределение года постройки

# %%
plt.hist(df['yr_built'], bins=15)

plt.title('Распределение года постройки')
plt.xlabel('Год постройки')
plt.ylabel('Кол-во домов');

# %% [markdown]
# 2.1. Изучите распределение домов от наличия вида на набережную

# %%
data = df['waterfront'].value_counts()
plt.pie(data, autopct='%1.1f%%')
plt.title('Распределение домов от наличия вида на набережную')
plt.legend(data.index);

# %% [markdown]
# 2.2. Изучите распределение этажей домов

# %%
data = df['floors'].value_counts()
plt.pie(data, autopct='%1.1f%%')
plt.title('Распределение этажей домов')
plt.legend(data.index);

# %% [markdown]
# 2.3. Изучите распределение состояния домов

# %%
data = df['condition'].value_counts()
plt.pie(data, autopct='%1.1f%%')
plt.title('Распределение состояния домов')
plt.legend(data.index);

# %% [markdown]
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.

# %%
data = df.groupby('yr_built')['price'].mean().reset_index()

plt.plot(data['yr_built'],data['price'])

plt.title('Распределение стоимости от года постройки')
plt.xlabel('Год постройки')
plt.ylabel('Стоимость');

# %%
plt.scatter(df['grade'], df['price'])
plt.title('Распределение стоимости от оценки')
plt.xlabel('Оценка')
plt.ylabel('Стоимость');

# %%
counts = df['condition'].value_counts()

plt.title('condition')
sns.barplot(x=counts.index, y=counts.values)

plt.title('Распределение оценки домов')
plt.xlabel('Оценка')
plt.ylabel('Количество');

# %%
#Распределение стоимости от площади дома
sns.jointplot(x=df['price'], y=df['sqft_lot'], kind='reg')
plt.xlabel('Стоимость')
plt.ylabel('Площадь');
